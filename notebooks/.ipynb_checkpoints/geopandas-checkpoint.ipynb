# %%
import geopandas as gpd

# %%
rj = gpd.read_file('../data/Mapas/RJ/33MUE250GC_SIR.shp')

# %%
rj.plot()
# Out:
# <AxesSubplot:>

# %%
with open('../data/Mapas/RJ/teste.dat','w') as f:
    f.write('asdasdadad')
